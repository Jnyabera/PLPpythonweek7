# %%
import pandas as pd

#loading data set
df = pd.read_csv("spotify.csv")

#printing the first five columns
print(df.head())

#checking datatypes on each column
print(df.dtypes)

#Check for missing values
print(df.isnull().sum())

#filling missing values
df['genres'].fillna('unknown', inplace=True)

#confirming if there's any missing value
print(df.isnull().sum())
# Out:
#    Unnamed: 0    artist_name genres  followers  artist_popularity  \
# 0           0  Ariana Grande    pop   98934105                 89
# 1           1  Ariana Grande    pop   98934105                 85
# 2           2  Ariana Grande    pop   98934105                 83
# 3           3  Ariana Grande    pop   98934105                 80
# 4           4  Ariana Grande    pop   98934105                 79
#
#                                           artist_url  \
# 0  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 1  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 2  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 3  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 4  https://open.spotify.com/artist/66CXWjxzNUsdJx...
#
#                                           track_name            album_name  \
# 0           we can't be friends (wait for your love)      eternal sunshine
# 1                                    the boy is mine      eternal sunshine
# 2                           intro (end of the world)      eternal sunshine
# 3  Save Your Tears (Remix) (with Ariana Grande) -...  After Hours (Deluxe)
# 4                                          yes, and?      eternal sunshine
#
#   release_date  duration_ms  ...  energy  key  loudness  mode  speechiness  \
# 0     3/8/2024       228639  ...   0.646    5    -8.334     1       0.0427
# 1     3/8/2024       173639  ...   0.630    7    -5.854     0       0.0434
# 2     3/8/2024        92400  ...   0.362   10    -9.480     1       0.0416
# 3    3/20/2020       191013  ...   0.825    0    -4.645     1       0.0325
# 4     3/8/2024       214994  ...   0.775    1    -6.614     1       0.0548
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0615          0.000030    0.0740    0.295  115.842
# 1        0.1570          0.000000    0.0732    0.447   97.998
# 2        0.6700          0.000000    0.1760    0.385   84.726
# 3        0.0215          0.000024    0.0936    0.593  118.091
# 4        0.1900          0.000065    0.1130    0.787  118.998
#
# [5 rows x 23 columns]
# Unnamed: 0             int64
# artist_name           object
# genres                object
# followers              int64
# artist_popularity      int64
# artist_url            object
# track_name            object
# album_name            object
# release_date          object
# duration_ms            int64
# explicit                bool
# track_popularity       int64
# danceability         float64
# energy               float64
# key                    int64
# loudness             float64
# mode                   int64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# dtype: object
# Unnamed: 0             0
# artist_name            0
# genres               163
# followers              0
# artist_popularity      0
# artist_url             0
# track_name             0
# album_name             0
# release_date           0
# duration_ms            0
# explicit               0
# track_popularity       0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# dtype: int64
# Unnamed: 0           0
# artist_name          0
# genres               0
# followers            0
# artist_popularity    0
# artist_url           0
# track_name           0
# album_name           0
# release_date         0
# duration_ms          0
# explicit             0
# track_popularity     0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# dtype: int64
